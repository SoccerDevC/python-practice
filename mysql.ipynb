# %%
import mysql.connector as conn

# %%
mydb = conn.connect(host='localhost', user='abstract-programmer', passwd='Serumag@25',port=3306, ssl_disabled=True)

# %%
cursor = mydb.cursor()

# %%
cursor.execute('show databases')

# %% [markdown]
# OpenSSL 3.0.13 30 Jan 2024

# %%
cursor.fetchall()
# Out:
# [('ademnea_database',),
#  ('breeze_skeleton',),
#  ('information_schema',),
#  ('math_competition',),
#  ('mysql',),
#  ('performance_schema',),
#  ('python',),
#  ('sys',),
#  ('test',)]

# %%
cursor.execute('create database python')
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cursor.execute('create database python')
#
# File /usr/lib/python3/dist-packages/mysql/connector/cursor.py:569, in MySQLCursor.execute(self, operation, params, multi)
#     566     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     568 try:
# --> 569     self._handle_result(self._connection.cmd_query(stmt))
#     570 except errors.InterfaceError:
#     571     if self._connection._have_next_result:  # pylint: disable=W0212
#
# File /usr/lib/python3/dist-packages/mysql/connector/connection.py:553, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     551 if not isinstance(query, bytes):
#     552     query = query.encode('utf-8')
# --> 553 result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     555 if self._have_next_result:
# ...

# %%
cursor.execute('use python')

# %%
cursor.execute('create table student (name varchar(20), age int)')
cursor.execute('insert into student values("John", 25)')
cursor.execute('insert into student values("Jane", 22)')
cursor.execute('insert into student values("Paul", 27)')
cursor.execute('select * from student')
cursor.fetchall()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 cursor.execute('create table student (name varchar(20), age int)')
#       2 cursor.execute('insert into student values("John", 25)')
#       3 cursor.execute('insert into student values("Jane", 22)')
#
# File /usr/lib/python3/dist-packages/mysql/connector/cursor.py:569, in MySQLCursor.execute(self, operation, params, multi)
#     566     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     568 try:
# --> 569     self._handle_result(self._connection.cmd_query(stmt))
#     570 except errors.InterfaceError:
#     571     if self._connection._have_next_result:  # pylint: disable=W0212
#
# File /usr/lib/python3/dist-packages/mysql/connector/connection.py:553, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     551 if not isinstance(query, bytes):
# ...

# %%
mydb.commit()

# %%
cursor.execute('create table glass (col1 float, col2 float, col3 float,col4 float,col5 float,col6 float,col7 float,col8 float,col9 float,col10 float)')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 cursor.execute('create table glass (col1 float, col2 float, col3 float,col4 float,col5 float,col6 float,col7 float,col8 float,col9 float,col10 float)')
#
# File /usr/lib/python3/dist-packages/mysql/connector/cursor.py:569, in MySQLCursor.execute(self, operation, params, multi)
#     566     return self._execute_iter(self._connection.cmd_query_iter(stmt))
#     568 try:
# --> 569     self._handle_result(self._connection.cmd_query(stmt))
#     570 except errors.InterfaceError:
#     571     if self._connection._have_next_result:  # pylint: disable=W0212
#
# File /usr/lib/python3/dist-packages/mysql/connector/connection.py:553, in MySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     551 if not isinstance(query, bytes):
#     552     query = query.encode('utf-8')
# ...

# %%
import csv
with open('glass.csv','r') as f:
    glass_csv = csv.reader(f, delimiter='\n')
    next(glass_csv, None) 
    for i in glass_csv:
        print(i)
        cursor.execute(f'insert into glass values({str(i[0])}) ')
# Out:
# ['1.52101,13.64,4.49,1.1,71.78,0.06,8.75,0,0,1']
# ['1.51761,13.89,3.6,1.36,72.73,0.48,7.83,0,0,1']
# ['1.51618,13.53,3.55,1.54,72.99,0.39,7.78,0,0,1']
# ['1.51766,13.21,3.69,1.29,72.61,0.57,8.22,0,0,1']
# ['1.51742,13.27,3.62,1.24,73.08,0.55,8.07,0,0,1']
# ['1.51596,12.79,3.61,1.62,72.97,0.64,8.07,0,0.26,1']
# ['1.51743,13.3,3.6,1.14,73.09,0.58,8.17,0,0,1']
# ['1.51756,13.15,3.61,1.05,73.24,0.57,8.24,0,0,1']
# ['1.51918,14.04,3.58,1.37,72.08,0.56,8.3,0,0,1']
# ['1.51755,13,3.6,1.36,72.99,0.57,8.4,0,0.11,1']
# ['1.51571,12.72,3.46,1.56,73.2,0.67,8.09,0,0.24,1']
# ['1.51763,12.8,3.66,1.27,73.01,0.6,8.56,0,0,1']
# ['1.51589,12.88,3.43,1.4,73.28,0.69,8.05,0,0.24,1']
# ['1.51748,12.86,3.56,1.27,73.21,0.54,8.38,0,0.17,1']
# ['1.51763,12.61,3.59,1.31,73.29,0.58,8.5,0,0,1']
# ['1.51761,12.81,3.54,1.23,73.24,0.58,8.39,0,0,1']
# ['1.51784,12.68,3.67,1.16,73.11,0.61,8.7,0,0,1']
# ['1.52196,14.36,3.85,0.89,71.36,0.15,9.15,0,0,1']
# ['1.51911,13.9,3.73,1.18,72.12,0.06,8.89,0,0,1']
# ...

# %%
mydb.commit()

# %%
cursor.execute('select * from python.glass WHERE col10 BETWEEN 1.51684 AND 1.51686')

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('delete from python.glass WHERE col1 BETWEEN 1.51684 AND 1.51686')

# %%
cursor.execute('select * from python.glass where col10 = 1 ')
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 cursor.execute('select * from python.glass where col10 = 1 ')
#
# File /usr/lib/python3/dist-packages/mysql/connector/cursor.py:539, in MySQLCursor.execute(self, operation, params, multi)
#     536 if not self._connection:
#     537     raise errors.ProgrammingError("Cursor is not connected")
# --> 539 self._connection.handle_unread_result()
#     541 self._reset_result()
#     542 stmt = ''
#
# File /usr/lib/python3/dist-packages/mysql/connector/connection.py:1132, in MySQLConnection.handle_unread_result(self)
#    1130     self.consume_results()
#    1131 elif self.unread_result:
# -> 1132     raise errors.InternalError("Unread result found")
#
# InternalError: Unread result found

# %%
cursor.fetchall()
# Out:
# [(1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 1.0),
#  (1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 1.0),
#  (1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 1.0),
#  (1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 1.0),
#  (1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 1.0),
#  (1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 1.0),
#  (1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 1.0),
#  (1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 1.0),
#  (1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 1.0),
#  (1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 1.0),
#  (1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 1.0),
#  (1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 1.0),
#  (1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 1.0),
#  (1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 1.0),
#  (1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 1.0),
# ...

# %%
cursor.execute('delete from python.glass where col2 = 13.3')

# %%
cursor.execute('select * from python.glass where col2 = 13.3')

# %%
cursor.fetchall()
# Out:
# []

# %%
cursor.execute('update python.glass set col10 = 4 where col10 =1')

# %%
cursor.execute('select * from python.glass where col10 = 4')
cursor.fetchall()
# Out:
# [(1.52101, 13.64, 4.49, 1.1, 71.78, 0.06, 8.75, 0.0, 0.0, 4.0),
#  (1.51761, 13.89, 3.6, 1.36, 72.73, 0.48, 7.83, 0.0, 0.0, 4.0),
#  (1.51618, 13.53, 3.55, 1.54, 72.99, 0.39, 7.78, 0.0, 0.0, 4.0),
#  (1.51766, 13.21, 3.69, 1.29, 72.61, 0.57, 8.22, 0.0, 0.0, 4.0),
#  (1.51742, 13.27, 3.62, 1.24, 73.08, 0.55, 8.07, 0.0, 0.0, 4.0),
#  (1.51596, 12.79, 3.61, 1.62, 72.97, 0.64, 8.07, 0.0, 0.26, 4.0),
#  (1.51743, 13.3, 3.6, 1.14, 73.09, 0.58, 8.17, 0.0, 0.0, 4.0),
#  (1.51756, 13.15, 3.61, 1.05, 73.24, 0.57, 8.24, 0.0, 0.0, 4.0),
#  (1.51918, 14.04, 3.58, 1.37, 72.08, 0.56, 8.3, 0.0, 0.0, 4.0),
#  (1.51755, 13.0, 3.6, 1.36, 72.99, 0.57, 8.4, 0.0, 0.11, 4.0),
#  (1.51571, 12.72, 3.46, 1.56, 73.2, 0.67, 8.09, 0.0, 0.24, 4.0),
#  (1.51763, 12.8, 3.66, 1.27, 73.01, 0.6, 8.56, 0.0, 0.0, 4.0),
#  (1.51589, 12.88, 3.43, 1.4, 73.28, 0.69, 8.05, 0.0, 0.24, 4.0),
#  (1.51748, 12.86, 3.56, 1.27, 73.21, 0.54, 8.38, 0.0, 0.17, 4.0),
#  (1.51763, 12.61, 3.59, 1.31, 73.29, 0.58, 8.5, 0.0, 0.0, 4.0),
# ...

# %%
cursor.execute('select col1, count(col1) from python.glass group by col1')
cursor.fetchall()
# Out:
# [(1.52101, 1),
#  (1.51761, 2),
#  (1.51618, 2),
#  (1.51766, 1),
#  (1.51742, 1),
#  (1.51596, 2),
#  (1.51743, 2),
#  (1.51756, 1),
#  (1.51918, 1),
#  (1.51755, 2),
#  (1.51571, 1),
#  (1.51763, 2),
#  (1.51589, 1),
#  (1.51748, 1),
#  (1.51784, 2),
#  (1.52196, 1),
#  (1.51911, 1),
#  (1.51735, 1),
#  (1.5175, 1),
#  (1.51966, 1),
#  (1.51736, 1),
#  (1.51751, 1),
#  (1.5172, 1),
#  (1.51764, 1),
#  (1.51793, 2),
#  (1.51721, 1),
#  (1.51768, 2),
#  (1.51747, 1),
#  (1.51775, 1),
#  (1.51753, 1),
#  (1.51783, 1),
#  (1.51567, 1),
#  (1.51909, 1),
#  (1.51797, 1),
#  (1.52213, 2),
#  (1.51779, 2),
#  (1.5221, 1),
#  (1.51786, 1),
#  (1.519, 1),
#  (1.51869, 1),
#  (1.52667, 1),
#  (1.52223, 1),
#  (1.51898, 1),
#  (1.5232, 1),
#  (1.51926, 1),
#  (1.51808, 1),
#  (1.51837, 1),
#  (1.51778, 1),
#  (1.51769, 2),
#  (1.51215, 1),
#  (1.51824, 1),
#  (1.51754, 2),
#  (1.51905, 2),
#  (1.51977, 1),
#  (1.52172, 2),
#  (1.52227, 1),
#  (1.52099, 1),
#  (1.52152, 3),
#  (1.523, 1),
# ...

# %%
cursor.execute("select * from python.glass where col1 like '1.51%'")

# %%
import sys
print(sys.version)
# Out:
# 3.12.3 (main, Feb  4 2025, 14:48:35) [GCC 13.3.0]

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://conrad:Serumaga25@cluster0.niz86.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
print(client)
# Out:
# MongoClient(host=['cluster0-shard-00-00.niz86.mongodb.net:27017', 'cluster0-shard-00-01.niz86.mongodb.net:27017', 'cluster0-shard-00-02.niz86.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-vpimb2-shard-0', tls=True, server_api=<pymongo.server_api.ServerApi object at 0x78bea6159310>)

# %%
import pymongo
print(pymongo.__version__)
# Out:
# 4.11.1

# %%
db1 = client.test1

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
db2 = client['cono']

# %%
col1 = db2['ineuron_collection']

# %%
dict = {
    'name':'John',
    'age':25,
    'email':'cddavid2001@gmail.com',
    'phone':'+256704000000',
    "product": ["one neuron", "tech neuron", "kids neuron", "drone fleematics"],
    "company": "iNeuron intelligence limited",
}

# %%
col1.insert_one(dict)
# Out:
# InsertOneResult(ObjectId('67bc5661b1a104ab08649262'), acknowledged=True)

# %%
list = [
    {
    'name':'John',
    'age':25,
    'email':'cddavid2001@gmail.com',
    'phone':'+256704000000',
    "product": ["one neuron", "tech neuron", "kids neuron", "drone fleematics"],
    "company": "iNeuron intelligence limited",
},
{
    'name':'John',
    'age':25,
    'email':'cddavid2001@gmail.com',
    'phone':'+256704000000',
    "product": ["one neuron", "tech neuron", "kids neuron", "drone fleematics"],
    "company": "iNeuron intelligence limited",
},
{
    'name':'John',
    'age':25,
    'email':'cddavid2001@gmail.com',
    'phone':'+256704000000',
    "product": ["one neuron", "tech neuron", "kids neuron", "drone fleematics"],
    "company": "iNeuron intelligence limited",
},{
    'name':'John',
    'age':25,
    'email':'cddavid2001@gmail.com',
    'phone':'+256704000000',
    "product": ["one neuron", "tech neuron", "kids neuron", "drone fleematics"],
    "company": "iNeuron intelligence limited",
}
]

# %%
col1.insert_many(list)
# Out:
# InsertManyResult([ObjectId('67bc7649b1a104ab08649263'), ObjectId('67bc7649b1a104ab08649264'), ObjectId('67bc7649b1a104ab08649265'), ObjectId('67bc7649b1a104ab08649266')], acknowledged=True)

# %%
for i in col1.find({"name":{"$in":["John","Jane"]}}):
    print(i)
# Out:
# {'_id': ObjectId('67bc5661b1a104ab08649262'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# {'_id': ObjectId('67bc7649b1a104ab08649263'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# {'_id': ObjectId('67bc7649b1a104ab08649264'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# ...

# %%
for i in col1.find({"age":{"$gt":20}}):
    print(i)
# Out:
# {'_id': ObjectId('67bc5661b1a104ab08649262'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# {'_id': ObjectId('67bc7649b1a104ab08649263'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# {'_id': ObjectId('67bc7649b1a104ab08649264'), 'name': 'John', 'age': 25, 'email': 'cddavid2001@gmail.com', 'phone': '+256704000000', 'product': ['one neuron', 'tech neuron', 'kids neuron', 'drone fleematics'], 'company': 'iNeuron intelligence limited'}
# ...
